# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
np.random.randn(1000)
# Out:
# array([ 5.16914820e-01,  1.48041740e-01, -5.87951843e-01, -1.64664728e-01,
#         1.21294962e+00,  1.36813587e+00,  1.99434664e-01, -7.21248837e-01,
#        -4.44388917e-01,  9.42212282e-01,  1.21984515e+00,  9.00732640e-01,
#        -1.94311538e+00,  8.63063930e-02, -6.17053218e-01,  1.98715452e-01,
#        -1.45256274e+00, -7.67269021e-01,  1.51232608e+00,  1.00709650e+00,
#        -2.78611813e+00, -8.34773979e-02, -2.23196305e-01, -1.78239112e-01,
#        -4.36487321e-02, -5.05979838e-01,  2.43245068e+00, -9.70195175e-01,
#        -7.76521703e-02,  1.08525825e+00, -1.17555873e-01, -1.09043313e-01,
#         6.23907621e-01, -3.31781648e-01,  3.53901513e-02, -1.06688222e+00,
#         1.41966123e+00,  4.26548569e-01,  7.73210988e-01,  9.03584099e-01,
#        -9.04888634e-01,  2.42705086e-01, -1.03276398e+00,  1.42564316e+00,
#         5.20625001e-01, -3.52490116e-01,  3.60936996e-01,  1.53313350e+00,
# ...

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('2022/03/26',periods=1000))

# %%
df

# %%
df.plot()

# %%
df.plot(figsize=(20,20))

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df

# %%
df.plot()

# %%
df.plot(figsize= (20,20))

# %%
df.plot(kind='bar',figsize = (20,10))

# %%
df.head(10).plot( kind = 'bar',figsize = (20,10))

# %%
df.iloc[5:10].plot(kind='bar',figsize = (20,10))

# %%
df.iloc[5:10]

# %%
df.iloc[5:10].plot(kind = 'barh')

# %%
df.iloc[[5]].plot(kind='bar')

# %%
df.plot(kind='hist')

# %%
df['sepal_length'].plot(kind='hist')

# %%
df['sepal_length'].plot(kind='hist',orientation='horizndal')

# %%
df.hist(figsize= (10,10),color= 'b')

# %%
df.hist(figsize= (10,10),color= 'b', alpha = .5)

# %%
df.plot(kind= 'box')

# %%
df.plot(kind= 'box',color= {box='g',whiskers ='r'})

# %%
df.plot(kind='area',figsize=(20,10))

# %%
df.plot(kind='area',figsize=(20,10),alpha=.5)

# %%
df.plot(kind='area',figsize=(20,10),alpha=.5,stacked=False)

# %%
df.plot.scatter(x= 'sepal_length',y='petal_length')

# %%
df.head(2)

# %%
df.plot.scatter(x= 'sepal_length',y='petal_width')

# %%
df.plot.scatter(x= 'sepal_length',y='petal_length',c='sepal_width')

# %%
df.plot.scatter(x= 'sepal_length',y='petal_length',c='sepal_width',s=100)

# %%
df.plot.scatter(x= 'sepal_length',y='petal_length',c='sepal_width',s=df['petal_width']*100)

# %%
df.plot.hexbin(x= 'sepal_length',y='petal_length',C='sepal_width',grid=10)

# %%
df.iloc[0]

# %%
df1=df.drop(columns='species').iloc[0]

# %%
df1.plot(kind='pie')

# %%
# !pip install plotly

# %%
# !pip install cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !pip install chart_studio

# %%
df.iplot()
# Out:
# <div>                            <div id="e739df2f-aab0-4abf-8cec-7134203a1b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',mode='markers')
# Out:
# <div>                            <div id="4abf8425-79a1-4436-ae2b-b522f2e5418d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(mode='markers',kind='scatter')
# Out:
# <div>                            <div id="87dad0cf-8b3b-4a3f-b9a4-b5e14f4f262f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df=df.drop(columns=['species'])

# %%
df.iplot(kind='bubble',x='sepal_length',y='petal_length')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 12
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="7784e9d6-4e30-448b-9033-e02fb22de688" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iplot(kind='scatter3d',x='sepal_length',y='sepal_width',z='petal_length')
# Out:
# <div>                            <div id="ddcb2473-e406-41f3-a7f6-6e2da29d1fef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d',x='sepal_length',y='sepal_width',z='petal_length')
# Out:
# <div>                            <div id="5fba51f0-f48f-4c3c-80fc-f4ec1ae613c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
try to explore map graph and try to show and example 
(2-3 example)

# %%
https://calendly.com/sunny-savita/doubt-session

# %%
# !pip install pyshp
# Out:
# ...
#      |████████████████████████████████| 44 kB 224 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 2.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.8 MB 642 kB/s eta 0:00:01     |███████████████████████████     | 4.9 MB 6.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 6.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 16.6 MB 16 kB/s  eta 0:00:01     |████████████████████▌           | 10.6 MB 5.3 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np
import plotly
import cufflinks as cf
cf.go_offline()
import matplotlib.pyplot as plt
import seaborn as sns
#import shapefile as shp
#import json 
import geopandas as gpd
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df =pd.read_csv('https://gist.githubusercontent.com/erichurst/7882666/raw/5bdc46db47d9515269ab12ed6fb2850377fd869e/US%2520Zip%2520Codes%2520from%25202013%2520Government%2520Data')

# %%
df
# Out:
#          ZIP        LAT         LNG
# 0        601  18.180555  -66.749961
# 1        602  18.361945  -67.175597
# 2        603  18.455183  -67.119887
# 3        606  18.158345  -66.932911
# 4        610  18.295366  -67.125135
# ...      ...        ...         ...
# 33139  99923  56.002315 -130.041026
# 33140  99925  55.550204 -132.945933
# 33141  99926  55.138352 -131.470424
# 33142  99927  56.239062 -133.457924
# 33143  99929  56.370751 -131.693301
#
# [33144 rows x 3 columns]

# %%
df_geo = gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df.LNG,df.LAT))

# %%
# get built in dataset from geopandas
world_data =gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world_data
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# ...

# %%
world_data[world_data.continent=='North America']
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# 16    10646714  North America                     Haiti    HTI     19340.0
# 17    10734247  North America            Dominican Rep.    DOM    161900.0
# 19      329988  North America                   Bahamas    BHS      9066.0
# 22       57713  North America                 Greenland    GRL      2173.0
# 27   124574795  North America                    Mexico    MEX   2307000.0
# 33     3753142  North America                    Panama    PAN     93120.0
# 34     4930258  North America                Costa Rica    CRI     79260.0
# 35     6025951  North America                 Nicaragua    NIC     33550.0
# 36     9038741  North America                  Honduras    HND     43190.0
# ...

# %%
# plot world map
axis =world_data[world_data.continent=='North America'].plot(color='lightblue',edgecolor='black')
df_geo.plot(ax=axis,color='black')
plt.title('USA')

fig =plt.gcf()
fig.set_size_inches(20,10)
plt.show()

# %%
### responsive MAPabs

# %%
#!pip install folium

# %%
import folium as f
import pandas as pd

# %%
df2= pd.read_csv('https://raw.githubusercontent.com/jtemporal/folium-101/main/cities.csv')

# %%
df2
# Out:
#               name   latitude   longitude lived visited
# 0           Olinda  -7.998127  -34.908203   yes     yes
# 1           Recife  -8.052200  -34.928600   yes     yes
# 2            Miami  25.761700  -80.191800    no     yes
# 3         New York  40.712800  -74.006000   yes     yes
# 4             Graz  47.070700   15.439500    no     yes
# 5           Taipei  25.033000  121.565400    no     yes
# 6        São Paulo -23.550500  -46.633300    no     yes
# 7           Osasco -23.537200  -46.796200   yes     yes
# 8   Ribeirão Preto -21.170400  -47.810300   yes     yes
# 9    Florianópolis -27.598600  -48.518700    no     yes
# 10        Campinas -22.909900  -47.062600    no     yes
# 11        Salvador -12.977700  -38.501600   yes     yes
# 12          Maceió  -9.649800  -35.708900    no     yes
# 13  Belo Horizonte -19.916700  -43.934500    no     yes
# 14      São Carlos -22.008700  -47.890900    no     yes
# 15  Rio de Janeiro -22.906800  -43.172900   yes     yes
# ...

# %%
my_map = f.Map(location=[0,0],zoom_start=2)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for _,city in df2.iterrows():
    f.Marker(location=[city['latitude'],city['longitude']],
            popup=city['name'],
            tooltip=city['name'],
        icon= f.Icon(color=city['color'],prefix='fa',icon='circle')
            
            ).add_to(my_map)

# %%
def select_marker_color(row):
    if row['lived'] == 'yes':
        return 'pink'
    elif row['lived'] =='no' and row['visited']== 'yes':
        return 'purple'
    else:
        return 'blue'

# %%
df2['color']= df2.apply(select_marker_color,axis=1)
df2.head()
# Out:
#        name   latitude  longitude lived visited   color
# 0    Olinda  -7.998127 -34.908203   yes     yes    pink
# 1    Recife  -8.052200 -34.928600   yes     yes    pink
# 2     Miami  25.761700 -80.191800    no     yes  purple
# 3  New York  40.712800 -74.006000   yes     yes    pink
# 4      Graz  47.070700  15.439500    no     yes  purple

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
my_map.save('my_map.html')

# %%
m = f.Map(location=[40.730610, -73.935242], tiles='Stamen Toner',
                zoom_start=12, control_scale=True, prefer_canvas=True)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
